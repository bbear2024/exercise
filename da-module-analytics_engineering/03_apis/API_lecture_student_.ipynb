# %% [markdown]
# #  APIs

# %% [markdown]
# >### Warmup - JSON
# >1. What is JSON, and why is it used in programming?
# >       - JSON stands for **J**ava**S**cript **O**bject **N**otation.
# >       - JSON is a lightweight format for storing and transporting data.
# >       - JSON is often used when data is sent from a server to a web page.
# >       - JSON is an open standard data interchange format that is both human and machine-readable.
# >       - A JSON file has `.json`as its extension.
# >2. In the code, what data structure is used to represent an individual student’s information?
# >       - dictionary with different keys and values or list of values
# >3. How are key-value pairs used in dictionaries, both in Python and in JSON?
# >       - keys are charakteristic labels for the values
#
#
# **Additional Information**
#
# In the early 2000s, JSON was initially specified by Douglas Crockford. In 2013, JSON was standardized as ECMA-404, and RCF 8259 was published in 2017.
# https://www.w3schools.com/whatis/whatis_json.asp
# https://en.wikipedia.org/wiki/JSON
# https://www.json.org/json-en.html

# %%
#### The json.loads() function to parse the JSON string and convert it back to Python data structures (dictionaries and lists)
import json


# Creating student records
student1 = {
    "name": "Alice",
    "age": 15,
    "grade": 10,
    "subjects": ["Math", "Science", "History"]
}

student2 = {
    "name": "Bob",
    "age": 16,
    "grade": 11,
    "subjects": ["English", "Physics", "Geography"]
}

student3 = {
    "name": "Carol",
    "age": 14,
    "grade": 9,
    "subjects": ["Art", "Music", "PE"]
}

# Creating a list of student records
student_database = [student1, student2, student3]

# Converting the student database to JSON format
json_data = json.dumps(student_database, indent=4)

# Printing the JSON data
print(json_data)

# %% [markdown]
# #### The json.loads() function to parse the JSON string and convert it back to Python data structures (dictionaries and lists)

# %%
json.loads(json_data)

# %%
type(json_data)

# %% [markdown]
# ## Brainstorm Intro
#
# - What do you understand under API?

# %% [markdown]
# ### Terminology Alert:
#
#
# >#### API, WEB API, OpenAPI, REST, HTTP

# %% [markdown]
# ### What is an API?

# %% [markdown]
# > An API (short for Application Programming Interface) is a concept used to describe – essentially – a piece of intermediary software (the interface) that facilitates communication between 2 other pieces of software (the applications).
#
# > It is a set of programming code that enables a transmission between one sofware product and another.

# %% [markdown]
# However, this is a pretty broad definition, as technically:
# - Pandas is an API to Numpy,
# - Numpy is an API to the C programming language,
# - C is an API to assembly code, and so on...

# %% [markdown]
# Usually when talking about APIs, we mean **Web** APIs, e.g. used to get data from the internet.

# %% [markdown]
# > ### Whiteboard
# > ![image.png](attachment:image.png)

# %% [markdown]
# > ### or show this
# > ![image.png](attachment:image.png)
# > https://medium.com/@ama.thanu/what-is-an-api-how-does-it-work-f4ea552d741f

# %% [markdown]
# --------------------------------------------------------------

# %% [markdown]
# ### REST (Representational State Transfer) and RESTful API

# %% [markdown]
# REST is as an architectural approach to designing web services. REST is independent of any underlying protocol and is not necessarily tied to HTTP. However, most common REST API implementations use HTTP as the application protocol.
# https://learn.microsoft.com/en-us/azure/architecture/best-practices/api-design#what-is-rest

# %% [markdown]
# **What is a REST API?**
#
# REST (**RE**presentational **S**tate **T**ransfer) means an agreement about the protocol how the API works.
# It is the de facto standard for developing web APIs.
#
#
# It repurposes the httprotocol and allows for the CRUD operations (create, read, update delete).

# %% [markdown]
# **RESTful API** is an application program interface (API) that uses [HTTP requests methods](https://www.restapitutorial.com/lessons/httpmethods.htm) GET, PUT, POST and DELETE data.
#
# Every application which has CRUD(Create, Read, Update, Delete) operation has an API to create data, to get data, to update data or to delete data from database.

# %% [markdown]
# ------------------------------------------------------

# %% [markdown]
# ### Web API

# %% [markdown]
# A Web API typically means some kind of special website or URL that we use as a channel to get data from some company or web based program. We can write a Python program to retrieve data from the API.
#
# Put very bluntly, an API is a website providing data that is easy for a machine (e.g. python code) to understand (as opposed to a prettier, HTML-rendered, user interface for humans).

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %% [markdown]
# In summary, REST API is a specific type of Web API that adheres to the principles of Representational State Transfer, using HTTP methods and statelessness. Web API is a more general term that encompasses APIs exposed over the web, which may or may not follow REST principles and can use various protocols and data formats.

# %% [markdown]
# ------------------------------------------------------

# %% [markdown]
# ### HTTP (Hypertext Transfer Protocol)

# %% [markdown]
# HTTP is an established communication protocol between a client and a server. A client in this case is a browser and server is the place where you access data. HTTP is a network protocol used to deliver resources which could be files on the World Wide Web, whether they're HTML files, image files, query results, scripts, or other file types.
#
# A browser is an HTTP client because it sends requests to an HTTP server (Web server), which then sends responses back to the client.
#
# Web API is a set of stpecifications
# - Hypertext Transfer Protocol (HTTP) request messages,
# - along with a definition of the structure of response messages, usually in an XML or a JavaScript Object Notation (JSON) format.

# %% [markdown]
# ------------------------------------------------------

# %% [markdown]
# ### OpenAPI (optional: for self reading)

# %% [markdown]
# OpenAPI is a specification used for creating interfaces used in describing, producing, consuming, and visualizing RESTful APIs. It is also known as the swagger specification.
#
# Very informative about what OpenAPI is: https://document360.com/blog/open-api

# %% [markdown]
# ------------------------------------------------------

# %% [markdown]
# ## Request Library

# %% [markdown]
# The Python `requests` library is a popular third-party library that simplifies the process of making HTTP requests and working with HTTP responses. It provides a high-level interface for sending HTTP requests to web servers and receiving their responses. This library is widely used for tasks like fetching data from APIs, sending data to servers, and interacting with web resources.
# > #### Intro to request library:
# >- https://requests.readthedocs.io (Documentation)
# >- https://realpython.com/python-requests/
# >- https://www.geeksforgeeks.org/response-json-python-requests/

# %%
# pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\yuqin\miniconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yuqin\miniconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yuqin\miniconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yuqin\miniconda3\lib\site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuqin\miniconda3\lib\site-packages (from requests) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pprint # https://docs.python.org/3/library/pprint.html
import pandas as pd

# %% [markdown]
# ### Let's get some data from the VBB Berlin API!

# %% [markdown]
# For the API of VBB Berlin & Brandenburg we can get some data for Moritzplatz using this url:

# %%
api_url = 'https://v6.vbb.transport.rest/locations?query=moritzplatz'

# %% [markdown]
# [v6.vbb.transport.rest](https://v6.vbb.transport.rest) is a free to use REST API for the public transportation system of Berlin & Brandenburg, VBB. The API doesn't require a sign up or a token.

# %% [markdown]
# **Teachers Note:**
# All Transit APIs can be found her https://transport.rest/

# %%
response = requests.request("GET", api_url)

print(response.status_code)
# Out:
# 200

# %% [markdown]
# ### Using the Contents of Response

# %% [markdown]
# When you send a request using the requests library, you receive a response object that contains information about the server’s response.
# **All status codes can be found here:** https://http.cat/

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# The response objects allow you to access the contents of the response. Try them out!

# %%
# response.content # we can read the contents in raw form
print(response.text) # we can read the contents as text
#response.json() # we can translate response to json
# response.headers
# response.url
# Out:
# [
# 	{
# 		"type": "stop",
# 		"id": "900013101",
# 		"name": "U Moritzplatz (Berlin)",
# 		"location": {
# 			"type": "location",
# 			"id": "900013101",
# 			"latitude": 52.503737,
# 			"longitude": 13.410944
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": true,
# 			"tram": false,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:11000:900013101"
# 	},
# 	{
# 		"type": "location",
# 		"id": null,
# 		"latitude": 51.630893,
# 		"longitude": 13.706222,
# 		"address": "03238 Finsterwalde, Moritzplatz"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900057107",
# 		"name": "Dennewitzplatz (Berlin)",
# 		"location": {
# 			"type": "location",
# 			"id": "900057107",
# 			"latitude": 52.495907,
# 			"longitude": 13.366223
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": false,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:11000:900057107"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900215724",
# 		"name": "Pritzwalk, Bürgerplatz",
# 		"location": {
# 			"type": "location",
# 			"id": "900215724",
# 			"latitude": 53.153171,
# 			"longitude": 12.172922
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": false,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:12070:900215724"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900210681",
# 		"name": "Dallgow-Döberitz, Am Reitplatz",
# 		"location": {
# 			"type": "location",
# 			"id": "900210681",
# 			"latitude": 52.536862,
# 			"longitude": 13.076222
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": false,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:12063:900210681"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900210648",
# 		"name": "Dallgow-Döberitz, Goetheplatz",
# 		"location": {
# 			"type": "location",
# 			"id": "900210648",
# 			"latitude": 52.545878,
# 			"longitude": 13.064059
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": false,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:12063:900210648"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900210705",
# 		"name": "Dallgow-Döberitz, Lindhorstplatz",
# 		"location": {
# 			"type": "location",
# 			"id": "900210705",
# 			"latitude": 52.548071,
# 			"longitude": 13.072329
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": false,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:12063:210705"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900055101",
# 		"name": "U Viktoria-Luise-Platz (Berlin)",
# 		"location": {
# 			"type": "location",
# 			"id": "900055101",
# 			"latitude": 52.496168,
# 			"longitude": 13.343264
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": true,
# 			"tram": false,
# 			"bus": false,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:11000:900055101"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900029202",
# 		"name": "Moritzstr. (Berlin)",
# 		"location": {
# 			"type": "location",
# 			"id": "900029202",
# 			"latitude": 52.538606,
# 			"longitude": 13.200722
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": false,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:11000:900029202"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900310807",
# 		"name": "Fürstenwalde, Platz der Solidarität",
# 		"location": {
# 			"type": "location",
# 			"id": "900310807",
# 			"latitude": 52.336285,
# 			"longitude": 14.088829
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": false,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:12067:900310807"
# 	}
# ]

# %% [markdown]
#  for example we can save the `.text` content as a json file for later usage:

# %%
# saving as json file

with open('json_example.json', mode='w', encoding='utf-8') as f:
    f.write(response.text)

# %%
# to open a json file you nead to use json package function json.load()

with open("json_example.json", "r") as file:
    results_saved = json.load(file)

# %%
# let's  translate our original response to json

result = response.json()

# %%
result

# check also out the list items: result[0] and so on
# Out:
# [{'type': 'stop',
#   'id': '900013101',
#   'name': 'U Moritzplatz (Berlin)',
#   'location': {'type': 'location',
#    'id': '900013101',
#    'latitude': 52.503737,
#    'longitude': 13.410944},
#   'products': {'suburban': False,
#    'subway': True,
#    'tram': False,
#    'bus': True,
#    'ferry': False,
#    'express': False,
#    'regional': False},
#   'stationDHID': 'de:11000:900013101'},
#  {'type': 'location',
#   'id': None,
#   'latitude': 51.630893,
#   'longitude': 13.706222,
#   'address': '03238 Finsterwalde, Moritzplatz'},
#  {'type': 'stop',
#   'id': '900057107',
#   'name': 'Dennewitzplatz (Berlin)',
#   'location': {'type': 'location',
#    'id': '900057107',
#    'latitude': 52.495907,
#    'longitude': 13.366223},
#   'products': {'suburban': False,
#    'subway': False,
#    'tram': False,
#    'bus': True,
#    'ferry': False,
#    'express': False,
#    'regional': False},
#   'stationDHID': 'de:11000:900057107'},
#  {'type': 'stop',
#   'id': '900215724',
#   'name': 'Pritzwalk, Bürgerplatz',
#   'location': {'type': 'location',
#    'id': '900215724',
#    'latitude': 53.153171,
#    'longitude': 12.172922},
#   'products': {'suburban': False,
#    'subway': False,
#    'tram': False,
#    'bus': True,
#    'ferry': False,
#    'express': False,
#    'regional': False},
#   'stationDHID': 'de:12070:900215724'},
#  {'type': 'stop',
#   'id': '900210681',
#   'name': 'Dallgow-Döberitz, Am Reitplatz',
#   'location': {'type': 'location',
#    'id': '900210681',
#    'latitude': 52.536862,
#    'longitude': 13.076222},
#   'products': {'suburban': False,
#    'subway': False,
#    'tram': False,
#    'bus': True,
#    'ferry': False,
#    'express': False,
#    'regional': False},
#   'stationDHID': 'de:12063:900210681'},
#  {'type': 'stop',
#   'id': '900210648',
#   'name': 'Dallgow-Döberitz, Goetheplatz',
#   'location': {'type': 'location',
#    'id': '900210648',
#    'latitude': 52.545878,
#    'longitude': 13.064059},
#   'products': {'suburban': False,
#    'subway': False,
#    'tram': False,
#    'bus': True,
#    'ferry': False,
#    'express': False,
#    'regional': False},
#   'stationDHID': 'de:12063:900210648'},
#  {'type': 'stop',
#   'id': '900210705',
#   'name': 'Dallgow-Döberitz, Lindhorstplatz',
#   'location': {'type': 'location',
#    'id': '900210705',
#    'latitude': 52.548071,
#    'longitude': 13.072329},
#   'products': {'suburban': False,
#    'subway': False,
#    'tram': False,
#    'bus': True,
#    'ferry': False,
#    'express': False,
#    'regional': False},
#   'stationDHID': 'de:12063:210705'},
#  {'type': 'stop',
#   'id': '900055101',
#   'name': 'U Viktoria-Luise-Platz (Berlin)',
#   'location': {'type': 'location',
#    'id': '900055101',
#    'latitude': 52.496168,
#    'longitude': 13.343264},
#   'products': {'suburban': False,
#    'subway': True,
#    'tram': False,
#    'bus': False,
#    'ferry': False,
#    'express': False,
#    'regional': False},
#   'stationDHID': 'de:11000:900055101'},
#  {'type': 'stop',
#   'id': '900029202',
#   'name': 'Moritzstr. (Berlin)',
#   'location': {'type': 'location',
#    'id': '900029202',
#    'latitude': 52.538606,
#    'longitude': 13.200722},
#   'products': {'suburban': False,
#    'subway': False,
#    'tram': False,
#    'bus': True,
#    'ferry': False,
#    'express': False,
#    'regional': False},
#   'stationDHID': 'de:11000:900029202'},
#  {'type': 'stop',
#   'id': '900310807',
#   'name': 'Fürstenwalde, Platz der Solidarität',
#   'location': {'type': 'location',
#    'id': '900310807',
#    'latitude': 52.336285,
#    'longitude': 14.088829},
#   'products': {'suburban': False,
#    'subway': False,
#    'tram': False,
#    'bus': True,
#    'ferry': False,
#    'express': False,
#    'regional': False},
#   'stationDHID': 'de:12067:900310807'}]

# %%
pprint.pprint(result)
# Out:
# [{'id': '900013101',
#   'location': {'id': '900013101',
#                'latitude': 52.503737,
#                'longitude': 13.410944,
#                'type': 'location'},
#   'name': 'U Moritzplatz (Berlin)',
#   'products': {'bus': True,
#                'express': False,
#                'ferry': False,
#                'regional': False,
#                'suburban': False,
#                'subway': True,
#                'tram': False},
#   'stationDHID': 'de:11000:900013101',
#   'type': 'stop'},
#  {'address': '03238 Finsterwalde, Moritzplatz',
#   'id': None,
#   'latitude': 51.630893,
#   'longitude': 13.706222,
#   'type': 'location'},
#  {'id': '900057107',
#   'location': {'id': '900057107',
#                'latitude': 52.495907,
#                'longitude': 13.366223,
#                'type': 'location'},
#   'name': 'Dennewitzplatz (Berlin)',
#   'products': {'bus': True,
#                'express': False,
#                'ferry': False,
#                'regional': False,
#                'suburban': False,
#                'subway': False,
#                'tram': False},
#   'stationDHID': 'de:11000:900057107',
#   'type': 'stop'},
#  {'id': '900215724',
#   'location': {'id': '900215724',
#                'latitude': 53.153171,
#                'longitude': 12.172922,
#                'type': 'location'},
#   'name': 'Pritzwalk, Bürgerplatz',
#   'products': {'bus': True,
#                'express': False,
#                'ferry': False,
#                'regional': False,
#                'suburban': False,
#                'subway': False,
#                'tram': False},
#   'stationDHID': 'de:12070:900215724',
#   'type': 'stop'},
#  {'id': '900210681',
#   'location': {'id': '900210681',
#                'latitude': 52.536862,
#                'longitude': 13.076222,
#                'type': 'location'},
#   'name': 'Dallgow-Döberitz, Am Reitplatz',
#   'products': {'bus': True,
#                'express': False,
#                'ferry': False,
#                'regional': False,
#                'suburban': False,
#                'subway': False,
#                'tram': False},
#   'stationDHID': 'de:12063:900210681',
#   'type': 'stop'},
#  {'id': '900210648',
#   'location': {'id': '900210648',
#                'latitude': 52.545878,
#                'longitude': 13.064059,
#                'type': 'location'},
#   'name': 'Dallgow-Döberitz, Goetheplatz',
#   'products': {'bus': True,
#                'express': False,
#                'ferry': False,
#                'regional': False,
#                'suburban': False,
#                'subway': False,
#                'tram': False},
#   'stationDHID': 'de:12063:900210648',
#   'type': 'stop'},
#  {'id': '900210705',
#   'location': {'id': '900210705',
#                'latitude': 52.548071,
#                'longitude': 13.072329,
#                'type': 'location'},
#   'name': 'Dallgow-Döberitz, Lindhorstplatz',
#   'products': {'bus': True,
#                'express': False,
#                'ferry': False,
#                'regional': False,
#                'suburban': False,
#                'subway': False,
#                'tram': False},
#   'stationDHID': 'de:12063:210705',
#   'type': 'stop'},
#  {'id': '900055101',
#   'location': {'id': '900055101',
#                'latitude': 52.496168,
#                'longitude': 13.343264,
#                'type': 'location'},
#   'name': 'U Viktoria-Luise-Platz (Berlin)',
#   'products': {'bus': False,
#                'express': False,
#                'ferry': False,
#                'regional': False,
#                'suburban': False,
#                'subway': True,
#                'tram': False},
#   'stationDHID': 'de:11000:900055101',
#   'type': 'stop'},
#  {'id': '900029202',
#   'location': {'id': '900029202',
#                'latitude': 52.538606,
#                'longitude': 13.200722,
#                'type': 'location'},
#   'name': 'Moritzstr. (Berlin)',
#   'products': {'bus': True,
#                'express': False,
#                'ferry': False,
#                'regional': False,
#                'suburban': False,
#                'subway': False,
#                'tram': False},
#   'stationDHID': 'de:11000:900029202',
#   'type': 'stop'},
#  {'id': '900310807',
#   'location': {'id': '900310807',
#                'latitude': 52.336285,
#                'longitude': 14.088829,
#                'type': 'location'},
#   'name': 'Fürstenwalde, Platz der Solidarität',
#   'products': {'bus': True,
#                'express': False,
#                'ferry': False,
#                'regional': False,
#                'suburban': False,
#                'subway': False,
#                'tram': False},
#   'stationDHID': 'de:12067:900310807',
#   'type': 'stop'}]

# %% [markdown]
# > #### SIDEBAR:
# > online tools like https://jsonformatter.org/ can also help to review JSON

# %%
# try to add the json result to dataframe 

pd.DataFrame(result)
# Out:
#        type         id                                 name  \
# 0      stop  900013101               U Moritzplatz (Berlin)
# 1  location       None                                  NaN
# 2      stop  900057107              Dennewitzplatz (Berlin)
# 3      stop  900215724               Pritzwalk, Bürgerplatz
# 4      stop  900210681       Dallgow-Döberitz, Am Reitplatz
# 5      stop  900210648        Dallgow-Döberitz, Goetheplatz
# 6      stop  900210705     Dallgow-Döberitz, Lindhorstplatz
# 7      stop  900055101      U Viktoria-Luise-Platz (Berlin)
# 8      stop  900029202                  Moritzstr. (Berlin)
# 9      stop  900310807  Fürstenwalde, Platz der Solidarität
#
#                                             location  \
# 0  {'type': 'location', 'id': '900013101', 'latit...
# 1                                                NaN
# 2  {'type': 'location', 'id': '900057107', 'latit...
# 3  {'type': 'location', 'id': '900215724', 'latit...
# 4  {'type': 'location', 'id': '900210681', 'latit...
# 5  {'type': 'location', 'id': '900210648', 'latit...
# 6  {'type': 'location', 'id': '900210705', 'latit...
# 7  {'type': 'location', 'id': '900055101', 'latit...
# 8  {'type': 'location', 'id': '900029202', 'latit...
# 9  {'type': 'location', 'id': '900310807', 'latit...
#
#                                             products         stationDHID  \
# 0  {'suburban': False, 'subway': True, 'tram': Fa...  de:11000:900013101
# 1                                                NaN                 NaN
# 2  {'suburban': False, 'subway': False, 'tram': F...  de:11000:900057107
# 3  {'suburban': False, 'subway': False, 'tram': F...  de:12070:900215724
# 4  {'suburban': False, 'subway': False, 'tram': F...  de:12063:900210681
# 5  {'suburban': False, 'subway': False, 'tram': F...  de:12063:900210648
# 6  {'suburban': False, 'subway': False, 'tram': F...     de:12063:210705
# 7  {'suburban': False, 'subway': True, 'tram': Fa...  de:11000:900055101
# 8  {'suburban': False, 'subway': False, 'tram': F...  de:11000:900029202
# 9  {'suburban': False, 'subway': False, 'tram': F...  de:12067:900310807
#
#     latitude  longitude                          address
# 0        NaN        NaN                              NaN
# 1  51.630893  13.706222  03238 Finsterwalde, Moritzplatz
# 2        NaN        NaN                              NaN
# 3        NaN        NaN                              NaN
# 4        NaN        NaN                              NaN
# 5        NaN        NaN                              NaN
# 6        NaN        NaN                              NaN
# 7        NaN        NaN                              NaN
# 8        NaN        NaN                              NaN
# 9        NaN        NaN                              NaN

# %%
# try out pandas reading ability. Pandas can read JSON right from the API URL 

pd.read_json(api_url)
# Out:
#        type           id                                 name  \
# 0      stop  900013101.0               U Moritzplatz (Berlin)
# 1  location          NaN                                  NaN
# 2      stop  900057107.0              Dennewitzplatz (Berlin)
# 3      stop  900215724.0               Pritzwalk, Bürgerplatz
# 4      stop  900210681.0       Dallgow-Döberitz, Am Reitplatz
# 5      stop  900210648.0        Dallgow-Döberitz, Goetheplatz
# 6      stop  900210705.0     Dallgow-Döberitz, Lindhorstplatz
# 7      stop  900055101.0      U Viktoria-Luise-Platz (Berlin)
# 8      stop  900029202.0                  Moritzstr. (Berlin)
# 9      stop  900310807.0  Fürstenwalde, Platz der Solidarität
#
#                                             location  \
# 0  {'type': 'location', 'id': '900013101', 'latit...
# 1                                                NaN
# 2  {'type': 'location', 'id': '900057107', 'latit...
# 3  {'type': 'location', 'id': '900215724', 'latit...
# 4  {'type': 'location', 'id': '900210681', 'latit...
# 5  {'type': 'location', 'id': '900210648', 'latit...
# 6  {'type': 'location', 'id': '900210705', 'latit...
# 7  {'type': 'location', 'id': '900055101', 'latit...
# 8  {'type': 'location', 'id': '900029202', 'latit...
# 9  {'type': 'location', 'id': '900310807', 'latit...
#
#                                             products         stationDHID  \
# 0  {'suburban': False, 'subway': True, 'tram': Fa...  de:11000:900013101
# 1                                                NaN                 NaN
# 2  {'suburban': False, 'subway': False, 'tram': F...  de:11000:900057107
# 3  {'suburban': False, 'subway': False, 'tram': F...  de:12070:900215724
# 4  {'suburban': False, 'subway': False, 'tram': F...  de:12063:900210681
# 5  {'suburban': False, 'subway': False, 'tram': F...  de:12063:900210648
# 6  {'suburban': False, 'subway': False, 'tram': F...     de:12063:210705
# 7  {'suburban': False, 'subway': True, 'tram': Fa...  de:11000:900055101
# 8  {'suburban': False, 'subway': False, 'tram': F...  de:11000:900029202
# 9  {'suburban': False, 'subway': False, 'tram': F...  de:12067:900310807
#
#     latitude  longitude                          address
# 0        NaN        NaN                              NaN
# 1  51.630893  13.706222  03238 Finsterwalde, Moritzplatz
# 2        NaN        NaN                              NaN
# 3        NaN        NaN                              NaN
# 4        NaN        NaN                              NaN
# 5        NaN        NaN                              NaN
# 6        NaN        NaN                              NaN
# 7        NaN        NaN                              NaN
# 8        NaN        NaN                              NaN
# 9        NaN        NaN                              NaN

# %% [markdown]
# ### Are APIs free?

# %% [markdown]
# there are
# - Free APIs (Meteostat API https://dev.meteostat.net/api/)
# - Paid APIs (Bloomberg API https://www.bloomberg.com/professional/)
# - Hybrid APIs (OpenWeatherAPI https://openweathermap.org/api)

# %% [markdown]
# ### What to consider when searching for an API?

# %% [markdown]
# - How much data is available?
# - How much data can be retrieved in one call
# - Is there a call rate limit? (e.g. you are not allowed to make more than X requests per hour)
# - Does the API require authentication?
#     - Is the authentication difficult (username/password: easy; OAuth (more complex; need to create an account, generate authentication tokens)
# - Is there a fee? (e.g. you are charged X cents per request)
# - Is the documentation easy to understand? Usually a few example URLs are super valuable in trying to understand the syntax.
# - What type of data is returned? JSON is usually your best bet.

# %% [markdown]
# ### What makes a web API better than scraping?

# %% [markdown]
# - Interface is not meant for humans but for machines. This refers both, to
#     - requests (=> well defined way how to ask for information)
#     - and to data delivery (=> provides data in a **more machine-readable format**, mostly json)
# - For larger data providers (e.g. reddit) there are often
#     - helper libraries
#     - documentation and examples
#     - clear terms and conditions about what is allowed
# - From the point of view of the provider, APIs
#     - create visibility (e.g. for a hotel operator whose vacant rooms are to be found by a meta search engine)
#     - ...

# %% [markdown]
# ### How to *find* an interesting (web) API?

# %% [markdown]
# (Please have a look (!) and feel free to use your desired one for this week's project.)
# - just search the internet
# - have a look [here](https://apislist.com/). Tons of APIs!
# - or [here](https://dev.to/biplov/15-fun-apis-for-your-next-project-5053) Fun APIs!
# - But usually you want to start the other way round:
#  You know which data you want to scrape and specifically look for whether an API exists for this [data](https://spiced.space/bergamot-encoder/ds-course/chapters/final_project/datasets.html#datasets).

# %% [markdown]
# -------------------------------------

# %% [markdown]
# # Next Step:
#
# ### Exercise:  Signup and explore meteostat API
