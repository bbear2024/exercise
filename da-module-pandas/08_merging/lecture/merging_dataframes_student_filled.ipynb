# %% [markdown]
# # Lesson: Merging Dataframes

# %% [markdown]
# ### Objectives

# %% [markdown]
# - Concatenation
# - Merging - inner join
# - Merging - left join
# - Merging - right join
# - Merging - outer join

# %% [markdown]
# > ### Warm-up
# > - open a new jupyter notebook
# > - Do the "Glue tables together" warm up from the course material

# %%
import pandas as pd

# %% [markdown]
# #### Read the `penguins_mini.csv` (as df1) and `penguins_region.csv` (as df2) and check which columns and rows they have

# %%
df1 = pd.read_csv('../data/penguins_mini.csv')
df1
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex
# 0     Adelie  Torgersen              181.0       3750.0    male
# 1     Adelie      Dream              178.0       3900.0    male
# 2     Gentoo     Biscoe              211.0       4500.0  female
# 3     Gentoo     Biscoe              230.0       5700.0    male
# 4  Chinstrap      Dream              192.0       3500.0  female

# %%
df2 = pd.read_csv('../data/penguins_region.csv')
df2
# Out:
#        species            region
# 0       Adelie            Anvers
# 1         King  Tierra del Fuego
# 2      Emperor       Weddell sea
# 3    Chinstrap            Anvers
# 4       Gentoo            Anvers
# 5  Little Blue   Roaring Forties

# %% [markdown]
# The `concat` function can be compared to what `.append()` is for lists.

# %%
numbers =[1,5,8,9]
letters =["h", "a", "b"]

# %%
# append the list `letters` to the list 'numbers' 

numbers.append(letters)

# %%
numbers.extend(letters)

# %%
numbers
# Out:
# [1, 5, 8, 9, ['h', 'a', 'b'], 'h', 'a', 'b']

# %%
# using append on our two dataframes...

df1.append(df1) # doesn't work
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 # using append on our two dataframes...
# ----> 3 df1.append(df1) # doesn't work
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# ## 1. Concatenation

# %% [markdown]
# - concatenate pandas dataframes along a particular axis with optional set logic along the other axes
# - axis = 0 is vertically and axis = 1 is horizontally
# - can combine multiple dataframes
# - there are several parameters that decide how the concatenation is done, most important are **axis**, **ignore_index** and **sort**
# - main use when **axis=0** (or axis='rows') is when df1 and df2 have the **same columns**
# - main use when **axis = 1** (or axis='columns') is when df1 and df2 have the **different columns** of the same observations

# %%
# concatenate df1 and df2


pd.concat([df1, df2])
# Out:
#        species     island  flipper_length_mm  body_mass_g     sex  \
# 0       Adelie  Torgersen              181.0       3750.0    male
# 1       Adelie      Dream              178.0       3900.0    male
# 2       Gentoo     Biscoe              211.0       4500.0  female
# 3       Gentoo     Biscoe              230.0       5700.0    male
# 4    Chinstrap      Dream              192.0       3500.0  female
# 0       Adelie        NaN                NaN          NaN     NaN
# 1         King        NaN                NaN          NaN     NaN
# 2      Emperor        NaN                NaN          NaN     NaN
# 3    Chinstrap        NaN                NaN          NaN     NaN
# 4       Gentoo        NaN                NaN          NaN     NaN
# 5  Little Blue        NaN                NaN          NaN     NaN
#
#              region
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 0            Anvers
# 1  Tierra del Fuego
# 2       Weddell sea
# 3            Anvers
# 4            Anvers
# 5   Roaring Forties

# %%
# use the 'axis' parameter (axis=0 or axis='rows')

pd.concat([df1, df2], axis=1)
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex      species  \
# 0     Adelie  Torgersen              181.0       3750.0    male       Adelie
# 1     Adelie      Dream              178.0       3900.0    male         King
# 2     Gentoo     Biscoe              211.0       4500.0  female      Emperor
# 3     Gentoo     Biscoe              230.0       5700.0    male    Chinstrap
# 4  Chinstrap      Dream              192.0       3500.0  female       Gentoo
# 5        NaN        NaN                NaN          NaN     NaN  Little Blue
#
#              region
# 0            Anvers
# 1  Tierra del Fuego
# 2       Weddell sea
# 3            Anvers
# 4            Anvers
# 5   Roaring Forties

# %%
# try axis=1

# %% [markdown]
# #### Can I concatenate 3 dataframes?

# %%
penguin_sweet = {
    'species': ['Adelie', 'Gentoo', 'Chinstrap'], 
    'sweetness': ['sweet', 'sweeter', 'sweetest']
}

df3 = pd.DataFrame(penguin_sweet)
df3
# Out:
#      species sweetness
# 0     Adelie     sweet
# 1     Gentoo   sweeter
# 2  Chinstrap  sweetest

# %%
# concatenate 3 dataframes

pd.concat([df1, df2, df3], axis=1)
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex      species  \
# 0     Adelie  Torgersen              181.0       3750.0    male       Adelie
# 1     Adelie      Dream              178.0       3900.0    male         King
# 2     Gentoo     Biscoe              211.0       4500.0  female      Emperor
# 3     Gentoo     Biscoe              230.0       5700.0    male    Chinstrap
# 4  Chinstrap      Dream              192.0       3500.0  female       Gentoo
# 5        NaN        NaN                NaN          NaN     NaN  Little Blue
#
#              region    species sweetness
# 0            Anvers     Adelie     sweet
# 1  Tierra del Fuego     Gentoo   sweeter
# 2       Weddell sea  Chinstrap  sweetest
# 3            Anvers        NaN       NaN
# 4            Anvers        NaN       NaN
# 5   Roaring Forties        NaN       NaN

# %% [markdown]
# #### Adding Parameters

# %%
# concatenate df1 and df2 adding the 'ignore_index' and the 'sort' parameters

pd.concat([df1, df2, df3], axis=0, ignore_index=True).fillna('-')
# Out:
#         species     island flipper_length_mm body_mass_g     sex  \
# 0        Adelie  Torgersen             181.0      3750.0    male
# 1        Adelie      Dream             178.0      3900.0    male
# 2        Gentoo     Biscoe             211.0      4500.0  female
# 3        Gentoo     Biscoe             230.0      5700.0    male
# 4     Chinstrap      Dream             192.0      3500.0  female
# 5        Adelie          -                 -           -       -
# 6          King          -                 -           -       -
# 7       Emperor          -                 -           -       -
# 8     Chinstrap          -                 -           -       -
# 9        Gentoo          -                 -           -       -
# 10  Little Blue          -                 -           -       -
# 11       Adelie          -                 -           -       -
# 12       Gentoo          -                 -           -       -
# 13    Chinstrap          -                 -           -       -
#
#               region sweetness
# 0                  -         -
# 1                  -         -
# 2                  -         -
# 3                  -         -
# 4                  -         -
# 5             Anvers         -
# 6   Tierra del Fuego         -
# 7        Weddell sea         -
# 8             Anvers         -
# 9             Anvers         -
# 10   Roaring Forties         -
# 11                 -     sweet
# 12                 -   sweeter
# 13                 -  sweetest

# %%
pd.concat([df1, df2, df3], axis=0, ignore_index=True, sort=True).fillna('-')
# Out:
#    body_mass_g flipper_length_mm     island            region     sex  \
# 0       3750.0             181.0  Torgersen                 -    male
# 1       3900.0             178.0      Dream                 -    male
# 2       4500.0             211.0     Biscoe                 -  female
# 3       5700.0             230.0     Biscoe                 -    male
# 4       3500.0             192.0      Dream                 -  female
# 5            -                 -          -            Anvers       -
# 6            -                 -          -  Tierra del Fuego       -
# 7            -                 -          -       Weddell sea       -
# 8            -                 -          -            Anvers       -
# 9            -                 -          -            Anvers       -
# 10           -                 -          -   Roaring Forties       -
# 11           -                 -          -                 -       -
# 12           -                 -          -                 -       -
# 13           -                 -          -                 -       -
#
#         species sweetness
# 0        Adelie         -
# 1        Adelie         -
# 2        Gentoo         -
# 3        Gentoo         -
# 4     Chinstrap         -
# 5        Adelie         -
# 6          King         -
# 7       Emperor         -
# 8     Chinstrap         -
# 9        Gentoo         -
# 10  Little Blue         -
# 11       Adelie     sweet
# 12       Gentoo   sweeter
# 13    Chinstrap  sweetest

# %% [markdown]
# ## 2. Merging - Inner Join

# %% [markdown]
# - will merge dataframes with a database-style **inner** join
# - one column must be in common between the dataframes
# - inner join means only taking the rows in common based on the join column

# %%
df1
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex
# 0     Adelie  Torgersen              181.0       3750.0    male
# 1     Adelie      Dream              178.0       3900.0    male
# 2     Gentoo     Biscoe              211.0       4500.0  female
# 3     Gentoo     Biscoe              230.0       5700.0    male
# 4  Chinstrap      Dream              192.0       3500.0  female

# %%
df2
# Out:
#        species            region
# 0       Adelie            Anvers
# 1         King  Tierra del Fuego
# 2      Emperor       Weddell sea
# 3    Chinstrap            Anvers
# 4       Gentoo            Anvers
# 5  Little Blue   Roaring Forties

# %% [markdown]
# ### adding a mismatch to the df1 : `Baby_Penguin` is not in the df2

# %%
df1.loc[5] = pd.Series(
{'species': 'Baby_Penguin',
 'island': 'Dream',
 'flipper_length_mm': 92.0,
 'body_mass_g': 1500.0,
 'sex': 'female'}

)

# %%
# option 1

pd.merge(left=df1, right=df2, how='inner', on='species')
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex  region
# 0     Adelie  Torgersen              181.0       3750.0    male  Anvers
# 1     Adelie      Dream              178.0       3900.0    male  Anvers
# 2     Gentoo     Biscoe              211.0       4500.0  female  Anvers
# 3     Gentoo     Biscoe              230.0       5700.0    male  Anvers
# 4  Chinstrap      Dream              192.0       3500.0  female  Anvers

# %%
# option 2
# using keyword arguments
df1.merge(right=df2, how='inner', on='species')
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex  region
# 0     Adelie  Torgersen              181.0       3750.0    male  Anvers
# 1     Adelie      Dream              178.0       3900.0    male  Anvers
# 2     Gentoo     Biscoe              211.0       4500.0  female  Anvers
# 3     Gentoo     Biscoe              230.0       5700.0    male  Anvers
# 4  Chinstrap      Dream              192.0       3500.0  female  Anvers

# %%
# or using positional arguments
df1.merge(df2, 'inner', 'species')
# Out:
#      species     island  flipper_length_mm  body_mass_g     sex  region
# 0     Adelie  Torgersen              181.0       3750.0    male  Anvers
# 1     Adelie      Dream              178.0       3900.0    male  Anvers
# 2     Gentoo     Biscoe              211.0       4500.0  female  Anvers
# 3     Gentoo     Biscoe              230.0       5700.0    male  Anvers
# 4  Chinstrap      Dream              192.0       3500.0  female  Anvers

# %% [markdown]
# ## 3. Left Join

# %% [markdown]
# - will merge dataframes with a database-style **left** join
# - one column must be in common between the dataframes
# - left join means taking all the rows in the left dataframe
# - missing rows from the right dataframe will be filled with null values

# %%
# option 1

pd.merge(left=df1, right=df2, how='left', on='species')
# Out:
#         species     island  flipper_length_mm  body_mass_g     sex  region
# 0        Adelie  Torgersen              181.0       3750.0    male  Anvers
# 1        Adelie      Dream              178.0       3900.0    male  Anvers
# 2        Gentoo     Biscoe              211.0       4500.0  female  Anvers
# 3        Gentoo     Biscoe              230.0       5700.0    male  Anvers
# 4     Chinstrap      Dream              192.0       3500.0  female  Anvers
# 5  Baby_Penguin      Dream               92.0       1500.0  female     NaN

# %%
# option 2

# df1.merge(left=df2... # try yourself

# %% [markdown]
# #### Using `indicator=True` to check how the dataframes were merged and if it corresponds to your expectations

# %%
pd.merge(left=df1, right=df2, how='left', on='species', indicator=True)
# Out:
#         species     island  flipper_length_mm  body_mass_g     sex  region  \
# 0        Adelie  Torgersen              181.0       3750.0    male  Anvers
# 1        Adelie      Dream              178.0       3900.0    male  Anvers
# 2        Gentoo     Biscoe              211.0       4500.0  female  Anvers
# 3        Gentoo     Biscoe              230.0       5700.0    male  Anvers
# 4     Chinstrap      Dream              192.0       3500.0  female  Anvers
# 5  Baby_Penguin      Dream               92.0       1500.0  female     NaN
#
#       _merge
# 0       both
# 1       both
# 2       both
# 3       both
# 4       both
# 5  left_only

# %% [markdown]
# ## 4. Right join

# %% [markdown]
# - will merge dataframes with a database-style **right** join
# - one column must be in common between the dataframes
# - right join means taking all the rows in the right dataframe
# - missing rows from the left dataframe will be filled with null values

# %%
# option 1
pd.merge(left=df1, right=df2, how='right', on='species', indicator=True)
# Out:
#        species     island  flipper_length_mm  body_mass_g     sex  \
# 0       Adelie  Torgersen              181.0       3750.0    male
# 1       Adelie      Dream              178.0       3900.0    male
# 2         King        NaN                NaN          NaN     NaN
# 3      Emperor        NaN                NaN          NaN     NaN
# 4    Chinstrap      Dream              192.0       3500.0  female
# 5       Gentoo     Biscoe              211.0       4500.0  female
# 6       Gentoo     Biscoe              230.0       5700.0    male
# 7  Little Blue        NaN                NaN          NaN     NaN
#
#              region      _merge
# 0            Anvers        both
# 1            Anvers        both
# 2  Tierra del Fuego  right_only
# 3       Weddell sea  right_only
# 4            Anvers        both
# 5            Anvers        both
# 6            Anvers        both
# 7   Roaring Forties  right_only

# %%
# option 2
# with the .merge() method it is always the left join, but you can flip the dataframes

# df2.merge(right=df1...

# %%
# add indicator=True

pd.merge(left=df1, right=df2, how='right', on='species', indicator=True)
# Out:
#        species     island  flipper_length_mm  body_mass_g     sex  \
# 0       Adelie  Torgersen              181.0       3750.0    male
# 1       Adelie      Dream              178.0       3900.0    male
# 2         King        NaN                NaN          NaN     NaN
# 3      Emperor        NaN                NaN          NaN     NaN
# 4    Chinstrap      Dream              192.0       3500.0  female
# 5       Gentoo     Biscoe              211.0       4500.0  female
# 6       Gentoo     Biscoe              230.0       5700.0    male
# 7  Little Blue        NaN                NaN          NaN     NaN
#
#              region      _merge
# 0            Anvers        both
# 1            Anvers        both
# 2  Tierra del Fuego  right_only
# 3       Weddell sea  right_only
# 4            Anvers        both
# 5            Anvers        both
# 6            Anvers        both
# 7   Roaring Forties  right_only

# %% [markdown]
# ## 5. Outer Join

# %% [markdown]
# - will merge dataframes with a database-style **outer** join
# - one column must be in common between the dataframes
# - outer join means taking all the rows from both dataframes
# - missing rows from both dataframes will be filled with null values

# %%
# option 1
pd.merge(left=df1, right=df2, how='outer', on='species', indicator=True)
# Out:
#         species     island  flipper_length_mm  body_mass_g     sex  \
# 0        Adelie  Torgersen              181.0       3750.0    male
# 1        Adelie      Dream              178.0       3900.0    male
# 2        Gentoo     Biscoe              211.0       4500.0  female
# 3        Gentoo     Biscoe              230.0       5700.0    male
# 4     Chinstrap      Dream              192.0       3500.0  female
# 5  Baby_Penguin      Dream               92.0       1500.0  female
# 6          King        NaN                NaN          NaN     NaN
# 7       Emperor        NaN                NaN          NaN     NaN
# 8   Little Blue        NaN                NaN          NaN     NaN
#
#              region      _merge
# 0            Anvers        both
# 1            Anvers        both
# 2            Anvers        both
# 3            Anvers        both
# 4            Anvers        both
# 5               NaN   left_only
# 6  Tierra del Fuego  right_only
# 7       Weddell sea  right_only
# 8   Roaring Forties  right_only

# %%
df1
# Out:
#         species     island  flipper_length_mm  body_mass_g     sex
# 0        Adelie  Torgersen              181.0       3750.0    male
# 1        Adelie      Dream              178.0       3900.0    male
# 2        Gentoo     Biscoe              211.0       4500.0  female
# 3        Gentoo     Biscoe              230.0       5700.0    male
# 4     Chinstrap      Dream              192.0       3500.0  female
# 5  Baby_Penguin      Dream               92.0       1500.0  female

# %%
pd.merge(left=df1, right=df2, how='outer', on='species', indicator=True)
# Out:
#         species     island  flipper_length_mm  body_mass_g     sex  \
# 0        Adelie  Torgersen              181.0       3750.0    male
# 1        Adelie      Dream              178.0       3900.0    male
# 2        Gentoo     Biscoe              211.0       4500.0  female
# 3        Gentoo     Biscoe              230.0       5700.0    male
# 4     Chinstrap      Dream              192.0       3500.0  female
# 5  Baby_Penguin      Dream               92.0       1500.0  female
# 6          King        NaN                NaN          NaN     NaN
# 7       Emperor        NaN                NaN          NaN     NaN
# 8   Little Blue        NaN                NaN          NaN     NaN
#
#              region      _merge
# 0            Anvers        both
# 1            Anvers        both
# 2            Anvers        both
# 3            Anvers        both
# 4            Anvers        both
# 5               NaN   left_only
# 6  Tierra del Fuego  right_only
# 7       Weddell sea  right_only
# 8   Roaring Forties  right_only

# %%
# sort=True will sort the rows on the 'species' column alphabetically 

pd.merge(left=df1, right=df2, how='outer', on='species', indicator=True, sort=True)
# Out:
#         species     island  flipper_length_mm  body_mass_g     sex  \
# 0        Adelie  Torgersen              181.0       3750.0    male
# 1        Adelie      Dream              178.0       3900.0    male
# 2  Baby_Penguin      Dream               92.0       1500.0  female
# 3     Chinstrap      Dream              192.0       3500.0  female
# 4       Emperor        NaN                NaN          NaN     NaN
# 5        Gentoo     Biscoe              211.0       4500.0  female
# 6        Gentoo     Biscoe              230.0       5700.0    male
# 7          King        NaN                NaN          NaN     NaN
# 8   Little Blue        NaN                NaN          NaN     NaN
#
#              region      _merge
# 0            Anvers        both
# 1            Anvers        both
# 2               NaN   left_only
# 3            Anvers        both
# 4       Weddell sea  right_only
# 5            Anvers        both
# 6            Anvers        both
# 7  Tierra del Fuego  right_only
# 8   Roaring Forties  right_only

# %%
# option 2

# df1.merge(left=df2... # try yourself
