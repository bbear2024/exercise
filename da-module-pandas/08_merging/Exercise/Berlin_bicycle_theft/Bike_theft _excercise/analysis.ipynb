# %%
Q1: How many bikes were stolen per year? per month?
Q2: How is the value per catagories? per area?

# %%
import pandas as pd
df = pd.read_csv('./bike_data/finish_list.csv')

# %%
df
# Out:
#       tatzeit_anfang_datum  tatzeit_anfang_stunde tatzeit_ende_datum  \
# 0               2020-01-01                      0         2020-01-01
# 1               2020-01-01                     22         2020-01-02
# 2               2020-01-01                     15         2020-01-02
# 3               2020-01-01                     15         2020-01-01
# 4               2020-01-01                      1         2020-01-01
# ...                    ...                    ...                ...
# 94206           2024-06-19                     15         2024-06-19
# 94207           2024-06-19                      9         2024-06-19
# 94208           2024-06-19                     16         2024-06-19
# 94209           2024-06-19                      7         2024-06-19
# 94210           2024-06-19                      8         2024-06-19
#
#        tatzeit_ende_stunde      lor  schadenshoehe    art_des_fahrrads  \
# ...

# %%
# find out which column is useless
df['delikt'].value_counts()
# Out:
# delikt
# Fahrraddiebstahl             89516
# Keller- und Bodeneinbruch     4695
# Name: count, dtype: int64

# %%
# drop useless columns
df = df.drop(['Unnamed: 0','versuch'], axis=1)

# %%
# drop duplicates
df.drop_duplicates(keep='first', inplace=True)
# Out:
#       tatzeit_anfang_datum  tatzeit_anfang_stunde tatzeit_ende_datum  \
# 0               2020-01-01                      0         2020-01-01
# 1               2020-01-01                     22         2020-01-02
# 2               2020-01-01                     15         2020-01-02
# 3               2020-01-01                     15         2020-01-01
# 4               2020-01-01                      1         2020-01-01
# ...                    ...                    ...                ...
# 94206           2024-06-19                     15         2024-06-19
# 94207           2024-06-19                      9         2024-06-19
# 94208           2024-06-19                     16         2024-06-19
# 94209           2024-06-19                      7         2024-06-19
# 94210           2024-06-19                      8         2024-06-19
#
#        tatzeit_ende_stunde      lor  schadenshoehe    art_des_fahrrads  \
# ...

# %%
# Translate column names into English
df.columns
['crime_time_start_date','crime_time_start_hour','crime_time_end_date','crime_time_end_hour','lor','amount_of_damage','type_of_bicycle','offense/crime','district','district_region','planning_area']
# Out:
# Index(['tatzeit_anfang_datum', 'tatzeit_anfang_stunde', 'tatzeit_ende_datum',
#        'tatzeit_ende_stunde', 'lor', 'schadenshoehe', 'art_des_fahrrads',
#        'delikt', 'bezirk', 'bezirksregion (name)', 'planungsraum (name)'],
#       dtype='object')

# %%
# change column names to lower case
df.columns = df.columns.str.lower()

# %%
# check how many bikes were stolen per year
# def mask(df, year):
#     m = (df.tatzeit_anfang_datum >= f'{year}-01-01') & (df.tatzeit_anfang_datum <= f'{year}-12-31')
#     return df[m]

# df['year'] = df['date'].dt.year
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94137 entries, 0 to 94210
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tatzeit_anfang_datum   94137 non-null  object
#  1   tatzeit_anfang_stunde  94137 non-null  int64
#  2   tatzeit_ende_datum     94137 non-null  object
#  3   tatzeit_ende_stunde    94137 non-null  int64
#  4   lor                    94137 non-null  int64
#  5   schadenshoehe          94137 non-null  int64
#  6   art_des_fahrrads       94137 non-null  object
#  7   delikt                 94137 non-null  object
#  8   bezirk                 94137 non-null  object
#  9   bezirksregion (name)   94137 non-null  object
#  10  planungsraum (name)    94137 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 8.6+ MB

# %%
# Out:
#       tatzeit_anfang_datum  tatzeit_anfang_stunde tatzeit_ende_datum  \
# 0               2020-01-01                      0         2020-01-01
# 1               2020-01-01                     22         2020-01-02
# 2               2020-01-01                     15         2020-01-02
# 3               2020-01-01                     15         2020-01-01
# 4               2020-01-01                      1         2020-01-01
# ...                    ...                    ...                ...
# 21383           2020-12-31                     12         2021-01-02
# 21384           2020-12-31                     11         2020-12-31
# 21385           2020-12-31                     10         2020-12-31
# 21386           2020-12-31                     19         2021-01-01
# 21387           2020-12-31                     20         2020-12-31
#
#        tatzeit_ende_stunde       lor  schadenshoehe    art_des_fahrrads  \
# ...
